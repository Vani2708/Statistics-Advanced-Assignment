# %% [markdown]
# # **Useful NLP Libraries & Networks Assignment**

# %% [markdown]
# **Question 1: Compare and contrast NLTK and spaCy in terms of features, ease of use, and performance.**
#
# Answer:
# **NLTK (Natural Language Toolkit)** is a comprehensive NLP library mainly used for research and education. It provides many tools for tokenization, stemming, tagging, and parsing but often requires more manual setup.
#
# **spaCy** is a modern, production-ready NLP library designed for speed and efficiency. It provides built-in pipelines for tokenization, part-of-speech tagging, named entity recognition, and dependency parsing.

# %% [markdown]
# **Question 2: What is TextBlob and how does it simplify common NLP tasks like sentiment analysis and translation**?
#
# Answer:
# TextBlob is a Python library built on top of NLTK and Pattern that simplifies common NLP tasks. It provides easy-to-use APIs for sentiment analysis, part-of-speech tagging, translation, noun phrase extraction, and text classification. With only a few lines of code, users can analyze sentiment polarity, detect subjectivity, or translate text into other languages.

# %% [markdown]
# **Question 3: Explain the role of Stanford NLP in academic and industry NLP projects.**
#
# Answer:
# Stanford NLP provides advanced tools and models for tasks such as part-of-speech tagging, named entity recognition, dependency parsing, and sentiment analysis. In academia, it is widely used for linguistic research and experimentation, while in industry it helps build applications like chatbots, information extraction systems, and search engines due to its high accuracy and robust language models.

# %% [markdown]
# **Question 4: Describe the architecture and functioning of a Recurrent Neural Network (RNN).**
#
# Answer:
# A Recurrent Neural Network (RNN) is a type of neural network designed for sequential data such as text, speech, or time-series data.
#
# Key features:
#
# It processes input one element at a time.
#
# Each step uses the previous hidden state to remember past information.
#
# This allows the model to capture context and dependencies in sequences.
#
# **Architecture component:**
#
# Input layer – receives sequence data
#
# Hidden layer with recurrence – maintains memory of previous states
#
# Output layer – produces predictions
#
# RNNs are commonly used in language modeling, machine translation, and speech recognition.

# %% [markdown]
# **Question 5: What is the key difference between LSTM and GRU networks in NLP applications**?
#
# Answer:
# **LSTM** (Long Short-Term Memory) networks use three gates (input, forget, and output) to control information flow and maintain long-term memory.
#
# **GRU** (Gated Recurrent Unit) networks use two gates (update and reset) and have a simpler structure.
#
# Key difference:
# GRUs are computationally faster and simpler, while LSTMs are more powerful for capturing very long-term dependencies in text sequences.

# %% [markdown]
# **Question 6: Sentiment Analysis using TextBlob**

# %%
from textblob import TextBlob

text = """I had a great experience using the new mobile banking app.
The interface is intuitive, and customer support was quick to resolve my issue.
However, the app did crash once during a transaction, which was frustrating."""

analysis = TextBlob(text)

print("Polarity:", analysis.sentiment.polarity)
print("Subjectivity:", analysis.sentiment.subjectivity)
# Out:
# Polarity: 0.21742424242424244
# Subjectivity: 0.6511363636363636

# %% [markdown]
# **Question 10: Chatbot Architecture using LSTM/GRU and NLP libraries**
#
# Answer:
#
# To build a mental health chatbot, the system should understand user emotions and generate supportive responses.
#
# **Architecture Steps**
#
# **Text Preprocessing**
#
# Use spaCy or Stanford NLP for tokenization, lemmatization, and entity recognition.
#
# **Intent Detection**
#
# Use LSTM or GRU networks trained on labeled conversation data to classify user intent (stress, anxiety, greeting, etc.).
#
# **Sentiment Analysis**
#
# Detect emotional tone of user input to adjust responses.
#
# **Context Handling**
#
# RNN models (LSTM/GRU) maintain conversation history to understand context.
#
# **Response Generation**
#
# Use predefined response templates or generative models.
#
# **Safety Filtering**
#
# Detect crisis keywords and redirect users to professional help.
#
# **Pipeline**
#
# User Input → Preprocessing (spaCy) → Feature Extraction → LSTM/GRU Intent Model → Response Selection → Chatbot Reply
#
# This architecture allows the chatbot to understand user emotions, maintain conversation context, and provide meaningful responses.

# %% [markdown]
# **Question 9: spaCy NLP Pipeline**

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text = """Homi Jehangir Bhaba was an Indian nuclear physicist who played a key role
in the development of India’s atomic energy program. He was the founding director
of the Tata Institute of Fundamental Research (TIFR)."""

doc = nlp(text)

print("Tokens and Lemmas:")
for token in doc:
    print(token.text, "->", token.lemma_)

print("\nNamed Entities:")
for ent in doc.ents:
    print(ent.text, "-", ent.label_)
# Out:
# Tokens and Lemmas:
# Homi -> Homi
# Jehangir -> Jehangir
# Bhaba -> Bhaba
# was -> be
# an -> an
# Indian -> indian
# nuclear -> nuclear
# physicist -> physicist
# who -> who
# played -> play
# a -> a
# key -> key
# role -> role
#
#  ->
#
# in -> in
# the -> the
# development -> development
# of -> of
# India -> India
# ’s -> ’s
# atomic -> atomic
# energy -> energy
# program -> program
# . -> .
# He -> he
# was -> be
# the -> the
# founding -> found
# director -> director
#
#  ->
#
# of -> of
# the -> the
# Tata -> Tata
# Institute -> Institute
# of -> of
# Fundamental -> Fundamental
# Research -> Research
# ( -> (
# TIFR -> TIFR
# ) -> )
# . -> .
#
# Named Entities:
# Homi Jehangir Bhaba - FAC
# Indian - NORP
# India - GPE
# the Tata Institute of Fundamental Research - ORG

# %% [markdown]
# **Question 8: Basic LSTM model using Keras**

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
import numpy as np

texts = [
"I love this project",
"This is an amazing experience",
"I hate waiting in line",
"This is the worst service",
"Absolutely fantastic!"
]

labels = [1,1,0,0,1]

# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

sequences = tokenizer.texts_to_sequences(texts)
padded = pad_sequences(sequences, padding='post')

X = np.array(padded)
y = np.array(labels)

# Model
model = Sequential()
model.add(Embedding(input_dim=50, output_dim=8, input_length=X.shape[1]))
model.add(LSTM(16))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X, y, epochs=10, verbose=1)

print("Training Complete")
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.4000 - loss: 0.6948
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4000 - loss: 0.6936
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.6000 - loss: 0.6925
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6000 - loss: 0.6915
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6000 - loss: 0.6904
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6000 - loss: 0.6894
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.6000 - loss: 0.6883
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6000 - loss: 0.6873
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.6000 - loss: 0.6863
# Epoch 10/10
# ...

# %% [markdown]
# **Question 7: Tokenization and Frequency Distribution using NLTK**
