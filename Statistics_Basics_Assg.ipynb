# %% [markdown]
# # **Statistics Basic Assignment**

# %% [markdown]
# **Question 1: What is the difference between descriptive statistics and inferential statistics? Explain with examples.**
#
# Answer:
# Descriptive statistics summarize and organize data to describe its main features using measures such as mean, median, mode, and standard deviation. For example, calculating the average marks of students in a class is descriptive statistics.
#
# Inferential statistics use sample data to make predictions or generalizations about a larger population. For example, using survey responses from 100 customers to estimate satisfaction of all customers in a company.

# %% [markdown]
# **Question 2: What is sampling in statistics? Explain the differences between random and stratified sampling.**
#
# Answer:
# Sampling is the process of selecting a subset of individuals or observations from a population to analyze and draw conclusions about the entire population.
#
# Random Sampling:
# Every individual in the population has an equal chance of being selected. Example: randomly selecting 50 students from a school list.
#
# Stratified Sampling:
# The population is divided into groups (strata) based on characteristics such as age or gender, and samples are taken from each group. Example: selecting students separately from each grade level.

# %% [markdown]
# **Question 3: Define mean, median, and mode. Explain why these measures of central tendency are important.**
#
# Answer:
# The mean is the average value obtained by dividing the sum of all observations by the number of observations.
#
# The median is the middle value in a dataset when the data is arranged in ascending or descending order.
#
# The mode is the value that appears most frequently in a dataset.
#
# These measures are important because they summarize the central value of a dataset, making it easier to understand the overall distribution and compare different datasets.

# %% [markdown]
# **Question 4: Explain skewness and kurtosis. What does a positive skew imply about the data**?
#
# Answer:
# Skewness measures the asymmetry of a data distribution around its mean.
#
# Kurtosis measures the peakedness or flatness of a distribution compared to a normal distribution.
#
# A positive skew (right skew) means that the tail of the distribution extends toward the right side, indicating that a few unusually high values exist in the dataset.

# %% [markdown]
# Question 5: Implement a Python program to compute the mean, median, and mode of
# a given list of numbers.
#
# numbers = [12, 15, 12, 18, 19, 12, 20, 22, 19, 19, 24, 24, 24, 26, 28]

# %%
import statistics

numbers = [12, 15, 12, 18, 19, 12, 20, 22, 19, 19, 24, 24, 24, 26, 28]

mean_value = statistics.mean(numbers)
median_value = statistics.median(numbers)
mode_value = statistics.mode(numbers)

print("Mean:", mean_value)
print("Median:", median_value)
print("Mode:", mode_value)
# Out:
# Mean: 19.6
# Median: 19
# Mode: 12

# %% [markdown]
# **Question 6: Compute the covariance and correlation coefficient between the following **
#
# two datasets provided as lists in Python:
#
# list_x = [10, 20, 30, 40, 50]
#
# list_y = [15, 25, 35, 45, 60]

# %%
import numpy as np

list_x = [10, 20, 30, 40, 50]
list_y = [15, 25, 35, 45, 60]

covariance = np.cov(list_x, list_y)[0][1]
correlation = np.corrcoef(list_x, list_y)[0][1]

print("Covariance:", covariance)
print("Correlation Coefficient:", correlation)
# Out:
# Covariance: 275.0
# Correlation Coefficient: 0.995893206467704

# %% [markdown]
# Question 7: Write a Python script to draw a boxplot for the following numeric list and
# identify its outliers. Explain the result:
#
# data = [12, 14, 14, 15, 18, 19, 19, 21, 22, 22, 23, 23, 24, 26, 29, 35]
#
# Answer:
#
# The boxplot shows the distribution of the dataset using quartiles.
# The box represents the interquartile range (IQR), while the line inside shows the median.
#
# The value 35 appears far from the rest of the data and may be considered a potential outlier, since it lies significantly higher than most values.

# %%
import matplotlib.pyplot as plt

data = [12, 14, 14, 15, 18, 19, 19, 21, 22, 22, 23, 23, 24, 26, 29, 35]

plt.boxplot(data)
plt.title("Boxplot of Data")
plt.show()

# %% [markdown]
# Question 8: Question 8: You are working as a data analyst in an e-commerce company. The
# marketing team wants to know if there is a relationship between advertising spend and
# daily sales.
#
# ● Explain how you would use covariance and correlation to explore this
# relationship.
#
# ● Write Python code to compute the correlation between the two lists:
#
# advertising_spend = [200, 250, 300, 400, 500]
# daily_sales = [2200, 2450, 2750, 3200, 4000]
#
# Answer:
# Relationship between advertising spend and daily sales
# Explanation
#
# Covariance measures how two variables change together. If covariance is positive, both variables increase together.
#
# Correlation measures the strength and direction of the relationship, with values between -1 and 1.
#
# +1 → strong positive relationship
#
# 0 → no relationship
#
# −1 → strong negative relationship
#
# By computing correlation between advertising spend and daily sales, we can determine whether higher advertising leads to higher sales.

# %%
import numpy as np

advertising_spend = [200, 250, 300, 400, 500]
daily_sales = [2200, 2450, 2750, 3200, 4000]

correlation = np.corrcoef(advertising_spend, daily_sales)[0][1]

print("Correlation between Advertising Spend and Daily Sales:", correlation)
# Out:
# Correlation between Advertising Spend and Daily Sales: 0.9935824101653329

# %% [markdown]
# Question 9: Your team has collected customer satisfaction survey data on a scale of
# 1-10 and wants to understand its distribution before launching a new product.
#
# ● Explain which summary statistics and visualizations (e.g. mean, standard
# deviation, histogram) you’d use.
#
# ● Write Python code to create a histogram using Matplotlib for the survey data:
#
# survey_scores = [7, 8, 5, 9, 6, 7, 8, 9, 10, 4, 7, 6, 9, 8, 7]
#
# Answwer:
#
# To understand the distribution of customer satisfaction scores, we can use:
#
# Summary Statistics
#
# Mean – average satisfaction score
#
# Median – middle value of scores
#
# Standard Deviation – measures variability in scores
#
# Visualization
#
# Histogram – shows how frequently each score appears and helps identify the distribution pattern.

# %%
import matplotlib.pyplot as plt
import numpy as np

survey_scores = [7, 8, 5, 9, 6, 7, 8, 9, 10, 4, 7, 6, 9, 8, 7]

mean_score = np.mean(survey_scores)
std_dev = np.std(survey_scores)

print("Mean:", mean_score)
print("Standard Deviation:", std_dev)

plt.hist(survey_scores, bins=6, color='skyblue', edgecolor='black')
plt.title("Customer Satisfaction Survey Scores")
plt.xlabel("Scores")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 7.333333333333333
# Standard Deviation: 1.577621275493231
